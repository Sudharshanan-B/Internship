# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/media/data/Acad/Programming/Python/work/task2/data_set02.xlsx", sheet_name='Sheet1')
df.head()
# Out:
#    Count #  HRn  Rn  QRSAmpn  HRn-1  Rn-1  QRSAmpn-1  HRn-2  Rn-2  QRSAmpn-2  \
# 0        1   98  12     1.02     99    13       1.04     96    10       0.99
# 1        2   78  10     1.34     82    12       1.20     90    10       1.34
# 2        3   72   8     0.65     74    10       0.73     75     9       0.70
# 3        4   90  14     0.88     99    12       1.04     96    11       0.98
# 4        5  138  20     1.02    158    34       0.76    172    29       0.66
#
#    ...  Bin4  Bin5  Bin6  Bin7  Bin8  Bin9  Bin10  Class  Status  Unnamed: 30
# 0  ...  0.08  0.06  0.02  0.02  0.02  0.03   0.00      0       1          nsr
# 1  ...  0.05  0.08  0.02  0.02  0.05  0.03   0.00      0       1          nsr
# 2  ...  0.11  0.08  0.02  0.01  0.02  0.03   0.01      0       1          nsr
# 3  ...  0.10  0.02  0.01  0.01  0.01  0.00   0.00      0       1          nsr
# 4  ...  0.08  0.06  0.06  0.06  0.04  0.02   0.00      4       1           vf
#
# [5 rows x 31 columns]

# %% [markdown]
# # Histogram Block

# %%
x = df['Bin6'] + df['Bin7'] + df['Bin8']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of combined Bin 6, 7, 8')
plt.xlabel('Bin 6 + Bin 7 + Bin 8')
plt.ylabel('Class')
plt.show()

# %%
x = df['Bin4'] + df['Bin3'] + df['Bin2'] + df['Bin1'] + df['Bin5']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of combined Bin 6, 7, 8')
plt.xlabel('Bin 6 + Bin 7 + Bin 8')
plt.ylabel('Class')
plt.show()

# %%
x = df['Bin4'] + df['Bin3'] + df['Bin5']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of combined Bin 3, 4, 5')
plt.xlabel('Bin 3 + Bin 4 + Bin 5')
plt.ylabel('Class')
plt.show()

# %%
x = df['Bin1'] + df['Bin2']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of combined Bin 1, 2')
plt.xlabel('Bin 1 + Bin 2')
plt.ylabel('Class')
plt.show()

# %% [markdown]
# # Frequency Block

# %%
x = df['Mpfn-4'] + df['Mpfn-6'] + df['Mpfn-2'] + df['Mpfn'] + df['Mpfn-3'] + df['Mpfn-1'] + df['Mpfn-5']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of frequecy block')
plt.xlabel('all Mpfns')
plt.ylabel('Class')
plt.show()

# %%
x = df['Mpfn-1'] + df['Mpfn-2'] + df['Mpfn']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of frequecy block')
plt.xlabel('all Mpfns')
plt.ylabel('Class')
plt.show()

# %% [markdown]
# # Heart Rate Block

# %%
x = df['Rn'] + df['Rn-1'] + df['Rn-2']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of Rn in heart rate block')
plt.xlabel('all Rn\'s')
plt.ylabel('Class')
plt.show()

# %%
x = df['QRSAmpn'] + df['QRSAmpn-1'] + df['QRSAmpn-2']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of QRSAmpn in heart rate block')
plt.xlabel('all QRSAmpn\'s')
plt.ylabel('Class')
plt.show()

# %%
x = df['HRn'] + df['HRn-1'] + df['HRn-2']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of Hrn\'s in heart rate block')
plt.xlabel('all Hrn\'s')
plt.ylabel('Class')
plt.show()

# %% [markdown]
# # After Normalizing the data

# %%
from sklearn.preprocessing import MinMaxScaler

# Create an instance of MinMaxScaler
scaler = MinMaxScaler()

# Assuming 'column1' and 'column2' are the names of the columns you want to normalize
columns_to_normalize = df[['HRn-1', 'HRn-2', 'HRn', 'QRSAmpn-1', 'QRSAmpn-2', 'QRSAmpn', 'Rn-2', 'Rn', 'Rn-1']]

# Normalize the columns
normalized_columns = scaler.fit_transform(columns_to_normalize)

# Create new columns to store the normalized values
df['nHRn-1'] = normalized_columns[:, 0]
df['nHRn-2'] = normalized_columns[:, 1]
df['nHRn'] = normalized_columns[:, 2]
df['nQRSAmpn-1'] = normalized_columns[:, 3]
df['nQRSAmpn-2'] = normalized_columns[:, 4]
df['nQRSAmpn'] = normalized_columns[:, 5]
df['nRn-2'] = normalized_columns[:, 6]
df['nRn'] = normalized_columns[:, 7]
df['nRn-1'] = normalized_columns[:, 8]

# %%
x = df['nHRn'] + df['nHRn-1'] + df['nHRn-2'] + df['nQRSAmpn-1'] + df['nQRSAmpn-2'] + df['nQRSAmpn'] + df['nRn-2'] + df['nRn'] +df['nRn-1']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of Heart rate block')
plt.xlabel('all columns')
plt.ylabel('Class')
plt.show()

# %% [markdown]
# # Not so promising results

# %%
x = df['nRn'] + df['nQRSAmpn'] + df['nRn-2'] +df['nQRSAmpn-2'] + df['nRn-1'] +df['nQRSAmpn-1']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of combination of Rn and Hrn in heart rate block')
plt.xlabel('Rn + Hrn')
plt.ylabel('Class')
plt.show()

# %%
x = df['nHRn'] + df['nRn'] +df['nQRSAmpn']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of combination of Rn, HRn and QRSAmpn block')
plt.xlabel('Rn + HRn + QRSAmpn')
plt.ylabel('Class')
plt.show()

# %%
x = df['nHRn-2'] + df['nRn-2'] +df['nQRSAmpn-2']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of combination of Rn-2, HRn-2 and QRSAmpn-2 block')
plt.xlabel('Rn-2 + HRn-2 + QRSAmpn-2')
plt.ylabel('Class')
plt.show()

# %%
x = df['nHRn-1'] + df['nRn-1'] +df['nQRSAmpn-1']
y = df['Class']

# %%
# plot the scatter plot with different colors for each class
plt.scatter(x, y, c=y, cmap='viridis', s=50)
plt.title('Scatter plot of combination of Rn-1, HRn-1 and QRSAmpn-1 block')
plt.xlabel('Rn-1 + HRn-1 + QRSAmpn-1')
plt.ylabel('Class')
plt.show()

# %% [markdown]
# # Summary
#
# ### Heart Rate block :
# <ol>
#     <li>QRSAmpn's -> class 2</li>
#     <li>Rn's -> class 0</li>
#     <li>All heart rates blocks after normalization -> class 3</li>
# </ol>
#
# ### Frequency block :
# All columns -> all classes are divided
#
# ### Histogram block :
# <ol>
#     <li>Bin1 + Bin2 -> all classes are divided</li>
#     <li>Bin6 + Bin7 + Bin8 -> all classes divided</li>
# </ol>
#
# ### Hence given a row based on the above features from each block we can detect the class

# %% [markdown]
# # Rules

# %%
# Bin6 + 7 + 8: 

# >=0.03 && < 0.1 -> 0
# == 0 -> 2
# == 0.06 -> 3
# >= 0.1 -> 4

# Bin 1 + 2

# >= 0.61 && <= 0.7 -> 0
# > 0.71 && <= 1.0 -> 2
# == 0.67 -> 3
# >= 0.44 && <= 0.57 -> 4

# Mpfns

# >= 85 && <= 94 -> 0
# >= 5 && <= 23 -> 2 (91 -> outlier)
# >= 46 && <= 55 -> 4
# cant tell anything about 3

# Rn

# >= 23 && <= 37 -> 0
# cant tell Anything about other classes

# QRSAmpns

# >= 0.21 && <= 0.57 -> 2
# cant tell Anything about other classes

# All Heart Rate Block colums except SOI
# >= 6.172936 && <= 6.2308927 -> 3

row_index = 5 # Example row index
columns1 = ['Bin1', 'Bin2']  # Specify the column names
columns2 = ['Bin6', 'Bin7', 'Bin8']
columns3 = ['Mpfn', 'Mpfn-1', 'Mpfn-2', 'Mpfn-3', 'Mpfn-4', 'Mpfn-5', 'Mpfn-6']
columns4 = ['Rn', 'Rn-1', 'Rn-2']
columns5 = ['QRSAmpn', 'QRSAmpn-1', 'QRSAmpn-2']
columns6 = ['nHRn', 'nHRn-1', 'nHRn-2', 'nQRSAmpn', 'nQRSAmpn-1', 'nQRSAmpn-2', 'nRn', 'nRn-1', 'nRn-2']

# Sum the values of the specified columns in the given row
bin1_2 = df.loc[row_index, columns1].sum()
bin6_7_8 = df.loc[row_index, columns2].sum()
mpfns = df.loc[row_index, columns3].sum()
rns = df.loc[row_index, columns4].sum()
qrsampns = df.loc[row_index, columns5].sum()
heart_rate_block = df.loc[row_index, columns6].sum()

print(bin1_2)
print(bin6_7_8)
print(mpfns)
print(rns)
print(qrsampns)
print(heart_rate_block)

# Histogram block
if(bin1_2 >= 0.61 and bin1_2 < 0.7) :
    print("class 0(bin1_2)")

if(bin6_7_8 >= 0.03 and bin6_7_8 < 0.1) :
    print("class 0(bin6_7_8)")

if(bin1_2 > 0.71 and bin1_2 <= 1.0) :
    print("class 2(bin1_2)")

if(bin6_7_8 == 0) :
    print("class 2(bin6_7_8)")

if(bin1_2 >= 0.44 and bin1_2 <= 0.57) :
    print("class 4(bin1_2)")

if(bin6_7_8 >= 0.1) :
    print("class 4(bin6_7_8)")


# frequency Block
if(mpfns >= 85 and mpfns < 95) :
    print("class 0(mpfns)")

if(mpfns >= 5 and mpfns <= 23) :
    print("class 2(mpnfs)")

if(mpfns >= 46 and mpfns <= 55) :
    print("class 4(mpfns)")
    

# Heart rate block
if(rns >= 23 and rns <= 37) :
    print("class 0(rns)")
    
if(qrsampns >= 0.21 and qrsampns <= 0.57) :
    print("class 2(qrsampns)")

if(heart_rate_block >= 6.172936 and heart_rate_block <= 6.2308960 ) :
    print("class 3(hrb)")
# Out:
# 0.65
# 0.06
# 120
# 93
# 3.8100000000000005
# 4.42280961340114
# class 0(bin1_2)
# class 0(bin6_7_8)

# %% [markdown]
# # Rules - Updated

# %%
# Rn 
# >=19 && <= 37 -> 0

#Qrsampn
# >= 0.21 && <= 0.57 -> 2

# Bin 1 2
# >= 0.59 and <= 0.70 -> 0
# >= 0.19 and <= 0.20 -> 1

# Bin 3 4 5
# >= 0.22 && <= 0.32 -> 0
# >= 0.2 && <= 0.21 -> 1

# Hrn rn qrsampn - norm 
# >= 1.33 && <= 1.35 -> 4

#hrn rn qrsampn -2 - norm
# >= 1.61 && <= 1.68 -> 4

# hrn rn qrsampn -1 -norm 
# >= 0.901393 && <= 0.969540 || >= 1.44 && <= 1.48 -> 3

# all mpfns
# >= 85 && <= 100 -> 0
# >= 46 && <= 55 -> 4

#diff -> extra/new features (Bin 3, 4, 5), [(Hrn -1+ rn -1 + qrsampn-1) -> 3]

class_values = []  # List to store the values of the "Class" column
actual = 0
print("actual_value", end = '\t')
print("predicted_value")
for index, row in df.iterrows():
    class_value = row["Class"]  # Access the value of the "Class" column for the current row
    class_values.append(class_value)

for i in range(1,26,1):
    
    actual_value = class_values[i - 1]
    cl = [0,0,0,0,0]

    columns1 = ['Bin1', 'Bin2']  # Specify the column names
    columns2 = ['Bin3', 'Bin4', 'Bin5']
    columns3 = ['Mpfn', 'Mpfn-1', 'Mpfn-2', 'Mpfn-3', 'Mpfn-4', 'Mpfn-5', 'Mpfn-6']
    columns4 = ['Rn', 'Rn-1', 'Rn-2']
    columns5 = ['QRSAmpn', 'QRSAmpn-1', 'QRSAmpn-2']
    columns6 = ['nHRn-1', 'nQRSAmpn-1', 'nRn-1']
    columns7 = ['nHRn-2', 'nQRSAmpn-2', 'nRn-2']
    columns8 = ['nHRn', 'nQRSAmpn', 'nRn']
    
    row_index = i
    
    # Sum the values of the specified columns in the given row
    bin1_2 = df.loc[row_index, columns1].sum()
    bin3_4_5 = df.loc[row_index, columns2].sum()
    mpfns = df.loc[row_index, columns3].sum()
    rns = df.loc[row_index, columns4].sum()
    qrsampns = df.loc[row_index, columns5].sum()
    h_r_q_1 = df.loc[row_index, columns6].sum()
    h_r_q = df.loc[row_index, columns7].sum()
    h_r_q_2 = df.loc[row_index, columns8].sum()

    if(rns >= 19 and rns <= 37) :
        cl[0] += 1 
    if(bin1_2 >= 0.59 and bin1_2 <= 0.70) :
        cl[0] += 1
    if(bin3_4_5 >= 0.22 and bin3_4_5 <= 0.32) :
        cl[0] += 1
    if(mpfns >= 85 and mpfns <= 100):
        cl[0] += 1

    if(bin1_2 >= 0.19 and bin1_2 <= 0.20):
        cl[1] += 1
    if(bin3_4_5 >= 0.2 and bin3_4_5 <= 0.21):
        cl[1] += 1

    if(qrsampns >= 0.21 and qrsampns <= 0.57):
        cl[2] += 1

    if( (h_r_q_1 >= 0.901393 and h_r_q_1 <= 0.969540) or (h_r_q_1 >= 1.44 and h_r_q_1 <= 1.48) ):
        cl[3] += 1

    if(mpfns >= 46 and mpfns <= 55 ) :
        cl[4] += 1
    if(h_r_q_2 >= 1.61 and h_r_q_2 <= 1.68 ):
        cl[4] += 1
    if(h_r_q >= 1.33 and h_r_q <= 1.35):
        cl[4] += 1

    predicted_value = -1
    mx = 0
    for i in range(5):
        if(mx <= cl[i]):
            mx = cl[i]
            predicted_value = i

    print(actual_value, end = "\t\t")
    print(predicted_value)

    if(actual_value == predicted_value):
        actual += 1

print("accuracy : ", end = " ")
print( float(actual) / float(27) )
# Out:
# actual_value	predicted_value
# 0		0
# 0		0
# 0		0
# 0		4
# 4		0
# 3		0
# 2		0
# 2		0
# 3		0
# 0		0
# 0		0
# 0		4
# 4		2
# 2		2
# 2		2
# 2		4
# 4		2
# 2		0
# 0		0
# 3		4
# 3		1
# 1		1
# 1		3
# 3		4
# 2		0
# accuracy :  0.3333333333333333

# %% [markdown]
# # Rough Work

# %%
# Assuming 'class_column' is the name of the column representing the class
class_value = 3  # The specific class value you want to filter

# Filter the DataFrame based on the class
filtered_rows = df[df['Class'] == class_value]

# %%
print(filtered_rows)

# %%
# Filter rows where class is equal to 1
filtered_df = df[df['Class'] == 0]

# Select the desired columns 'b' and 'd' and calculate the row-wise sum
row_sums = filtered_df[['Rn', 'Rn-1', 'Rn-2']].sum(axis=1)

print("Row-wise sums of Rns where class = 0:")
print(row_sums)

# %%
# Filter rows where class is equal to 1
filtered_df = df[df['Class'] == 2]

# Select the desired columns 'b' and 'd' and calculate the row-wise sum
row_sums = filtered_df[['QRSAmpn', 'QRSAmpn-1', 'QRSAmpn-2']].sum(axis=1)

print("Row-wise sums of QRSAmpns where class = 2:")
print(row_sums)

# %%
# Filter rows where class is equal to 1
filtered_df = df[df['Class'] == 1]

# Select the desired columns 'b' and 'd' and calculate the row-wise sum
row_sums = filtered_df[['Bin1', 'Bin2']].sum(axis=1)

print("Row-wise sums of Bins1, 2 where class = 1:")
print(row_sums)

# %%
# Filter rows where class is equal to 1
filtered_df = df[df['Class'] == 0]

# Select the desired columns 'b' and 'd' and calculate the row-wise sum
row_sums = filtered_df[['Bin1', 'Bin2']].sum(axis=1)

print("Row-wise sums of Bins 1,2 where class = 0:")
print(row_sums)

# %%
# Filter rows where class is equal to 1
filtered_df = df[df['Class'] == 0]

# Select the desired columns 'b' and 'd' and calculate the row-wise sum
row_sums = filtered_df[['Bin4', 'Bin5', 'Bin3']].sum(axis=1)

print("Row-wise sums of Bins 4,5,3 where class = 0:")
print(row_sums)

# %%
# Filter rows where class is equal to 1
filtered_df = df[df['Class'] == 1]

# Select the desired columns 'b' and 'd' and calculate the row-wise sum
row_sums = filtered_df[['Bin4', 'Bin5', 'Bin3']].sum(axis=1)

print("Row-wise sums of Bins 4,5,3 where class = 1:")
print(row_sums)

# %%
# Filter rows where class is equal to 1
filtered_df = df[df['Class'] == 4]

# Select the desired columns 'b' and 'd' and calculate the row-wise sum
row_sums = filtered_df[['nHRn', 'nRn', 'nQRSAmpn']].sum(axis=1)

print("Row-wise sums of heart-rate hrn,rn,qrsampn where class = 4:")
print(row_sums)

# %%
# Filter rows where class is equal to 1
filtered_df = df[df['Class'] == 4]

# Select the desired columns 'b' and 'd' and calculate the row-wise sum
row_sums = filtered_df[['nHRn-2', 'nRn-2', 'nQRSAmpn-2']].sum(axis=1)

print("Row-wise sums of heart-rate hrn-2,rn-2,qrsampn-2 where class = 4:")
print(row_sums)

# %%
# Filter rows where class is equal to 1
filtered_df = df[df['Class'] == 3]

# Select the desired columns 'b' and 'd' and calculate the row-wise sum
row_sums = filtered_df[['nHRn-1', 'nRn-1', 'nQRSAmpn-1']].sum(axis=1)

print("Row-wise sums of heart-rate hrn-1,rn-1,qrsampn-1 where class = 3:")
print(row_sums)

# %%
# Filter rows where class is equal to 1
filtered_df = df[df['Class'] == 0]

# Select the desired columns 'b' and 'd' and calculate the row-wise sum
row_sums = filtered_df[['Mpfn', 'Mpfn-1', 'Mpfn-2', 'Mpfn-3', 'Mpfn-4', 'Mpfn-5', 'Mpfn-6']].sum(axis=1)

print("Row-wise sums of mpfns where class = 0:")
print(row_sums)

# %%
# Filter rows where class is equal to 1
filtered_df = df[df['Class'] == 4]

# Select the desired columns 'b' and 'd' and calculate the row-wise sum
row_sums = filtered_df[['Mpfn', 'Mpfn-1', 'Mpfn-2', 'Mpfn-3', 'Mpfn-4', 'Mpfn-5', 'Mpfn-6']].sum(axis=1)

print("Row-wise sums of mpfns where class = 4:")
print(row_sums)

# %%
import pandas as pd

# Assuming you have a DataFrame called "df" with columns including "Class"

class_values = []  # List to store the values of the "Class" column

for index, row in df.iterrows():
    class_value = row["Class"]  # Access the value of the "Class" column for the current row
    class_values.append(class_value)

# Print the values of the "Class" column
print(class_values)
